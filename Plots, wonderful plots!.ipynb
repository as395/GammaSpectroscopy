# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
'''Gilmore vs Semkow (Co-60)'''
fig, ax = plt.subplots()

N = 6
ind = np.arange(N)
width = .2


#R=10000
gilfull = ([6458.598253283848, 0.1547548314173005, 0.4841153786619365, 1249.9772763548024,6972.518751904781,0.7592245655541936])
go =  ([10755.307570350189, 0.09933990256648652, 1.1792812213075967,0.00013531657453033738,11620.624645536385,1.9332106997574101])
sfull = ([6.45859840e+03, 1.54754831e-01, 4.84115363e-01, 1.24997727e+03,6.97251854e+03,7.59224574e-01])
so = ([1.07560047e+04,9.93399029e-02,1.17928118e+00,1.35316582e-04,1.16206243e+04,1.93321072e+00])
# so = ([1.07553078e+04,9.93399029e-02,1.17928118e+00,1.35316582e-04, 1.16206243e+04,  1.93321072e+00])

rects1 = ax.bar(ind, gilfull, width, color='grey')
rects2 = ax.bar(ind + width, sfull, width, color='lightgrey') #yerr=women_std
rects3 = ax.bar(ind + 2*width, go, width, color='grey', hatch='x')
rects4 = ax.bar(ind + 3*width, so, width, color='lightgrey', hatch='x')


# add text for labels, title and axes ticks
ax.set_ylabel('Counts', size=20)
ax.set_xlabel('Photopeak Energies', size=20)
ax.set_title('Peak Intensities (R=100,000)', size=24)
ax.set_xticks(ind + width + width/2)
ax.set_xticklabels(('1332.508 keV','2158.61 keV','826.102 keV','2505.748 keV','1173.24 keV','347.138 keV'))
                    
ax.legend((rects1[0], rects2[0], rects3[0], rects4[0]), ('Full Summing', 'Semkow (Full Summing)', 'No Summing', 'Semkow (No Summing)'), fontsize=20)

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.005*height,
                '%d' % float(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
fig.set_size_inches(25, 15)
plt.show()

# %%
'''Gilmore vs Semkow (Co-60) LOG PLOT'''
fig, ax = plt.subplots()

N = 6
ind = np.arange(N)
width = .2


#R=10000
gfull = ([6458.598253283848, 0.1547548314173005, 0.4841153786619365, 1249.9772763548024,6972.518751904781,0.7592245655541936])
logGF = np.absolute(np.log10(np.multiply(100, gfull)))
go =  ([10755.307570350189, 0.09933990256648652, 1.1792812213075967,0.00013531657453033738,11620.624645536385,1.9332106997574101])
logGO = np.absolute(np.log10(np.multiply(100, go)))
sfull = ([6.45859840e+03, 1.54754831e-01, 4.84115363e-01, 1.24997727e+03,6.97251854e+03,7.59224574e-01])
logSF = np.absolute(np.log10(np.multiply(100, sfull)))
so = ([1.07560047e+04,9.93399029e-02,1.17928118e+00,1.35316582e-04,1.16206243e+04,1.93321072e+00])
logSO = np.absolute(np.log10(np.multiply(100, so)))
# so = ([1.07553078e+04,9.93399029e-02,1.17928118e+00,1.35316582e-04, 1.16206243e+04,  1.93321072e+00])

rects1 = ax.bar(ind, logGF, width, color='grey')
rects2 = ax.bar(ind + width, logSF, width, color='lightgrey') #yerr=women_std
rects3 = ax.bar(ind + 2*width, logGO, width, color='grey', hatch='x')
rects4 = ax.bar(ind + 3*width, logSO, width, color='lightgrey', hatch='x')


# add text for labels, title and axes ticks
ax.set_ylabel('| Log(Counts) |', size=24)
ax.set_xlabel('Photopeak Energies', size=24)
# ax.set_title('Relative Photopeak Counts (R=100,000)', size=24)
ax.set_xticks(ind + width + width/2)
ax.set_xticklabels(('1332.508 keV','2158.61 keV','826.102 keV','2505.748 keV','1173.24 keV','347.138 keV'), fontsize=16)
ax.set_yticklabels(('0','1','2','3','4','5','6'), fontsize=16)

ax.legend((rects1[0], rects2[0], rects3[0], rects4[0]), ('Full Summing', 'Semkow (Full Summing)', 'No Summing', 'Semkow (No Summing)'), fontsize=20)

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.005*height,
                '%d.2' % float(height),
                ha='center', va='bottom', fontsize=16)

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
fig.set_size_inches(25, 15)
plt.show()
